# %%
from flatsurf import *
import flatsurf
from flatsurf.geometry.similarity_surface_generators import TranslationSurfaceGenerators
from flatsurf.geometry.similarity_surface_generators import DilationSurfaceGenerators

# %%
s = TranslationSurfaceGenerators.square_torus()

# %%
s.plot()
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
# M = matrix([[1,3/2],[1,-1]])
# M
M = matrix([[1,4],[0,1]])
M
# Out:
# [1 4]
# [0 1]

# %%
s2 = M*s
s2.plot()
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
s3 = s2.canonicalize()
s2.plot()
s3 == s
# Out:
# True

# %%
M = matrix([[1,1],[0,1]])
M
s2 = M*s

# What is the difference here? :
s2.plot()
# show(s2.plot())
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
show(s2.plot())
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
s2c = s2.canonicalize()
s2c.plot()
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
s.canonicalize() == s2.canonicalize()
# Out:
# True

# %%
s = TranslationSurfaceGenerators.regular_octagon()
s.plot()
# Out:
# Graphics object consisting of 18 graphics primitives

# %%
R = s.base_ring()
R
# Out:
# Number Field in a with defining polynomial y^2 - 2 with a = 1.414213562373095?

# %%
a = R.gen()
a.n()
# Out:
# 1.41421356237309

# %%
M = matrix([[1,2+2*a],[0,1]])

# %%
s.canonicalize().plot()
# Out:
# Graphics object consisting of 18 graphics primitives

# %%
s2 = M*s
s2.plot()
# Out:
# Graphics object consisting of 18 graphics primitives

# %%
s2.canonicalize().plot()
# Out:
# Graphics object consisting of 18 graphics primitives

# %%
s.canonicalize() == s2.canonicalize()
# Out:
# True

# %%
s=translation_surfaces.veech_double_n_gon(5)

# %%
s.plot()
# Out:
# Graphics object consisting of 21 graphics primitives

# %%
a = 1/math.tan(math.pi/5)
M = matrix([[1,2*a],[0,1]])
N = M*s
# N.plot() + s.plot()
N.plot()
# Out:
# Graphics object consisting of 21 graphics primitives

# %%
O = N.canonicalize()
O.plot()
# Out:
# Graphics object consisting of 42 graphics primitives

# %%
gs = O.graphical_surface()

gs.make_adjacent(2,2)
gs.plot()

# gs.make_adjacent(3,3)
# Out:
# Graphics object consisting of 39 graphics primitives
